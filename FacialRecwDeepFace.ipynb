# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonwnc/ds2002s24/blob/main/FacialRecwDeepFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.3/94.3 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 27.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 10.2 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=e4f8266d05499d2d6ddf2c32c1136819ba222253e5a00efb7dce119ea704d732
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# 24-04-03 18:08:08 - Directory /root/.deepface created
# 24-04-03 18:08:08 - Directory /root/.deepface/weights created

# %%
img1_path = 'sample_data/img1.jpg'
img2_path = 'sample_data/AJyoung.jpg'

# %%
img1= DeepFace.detectFace(img1_path)
img2 = DeepFace.detectFace(img2_path)
# Out:
# 24-04-03 18:14:58 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.
# 24-04-03 18:15:00 - ⚠️ Function detectFace is deprecated. Use extract_faces instead.

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
model_name = "Facenet"
#model_name = "ArcFace"

# %%
resp = DeepFace.verify(img1_path=img1_path, img2_path=img2_path, model_name=model_name)

# %%
resp
# Out:
# {'verified': True,
#  'distance': 0.39030232056465863,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 345,
#    'y': 211,
#    'w': 769,
#    'h': 769,
#    'left_eye': (571, 517),
#    'right_eye': (853, 523)},
#   'img2': {'x': 53,
#    'y': 30,
#    'w': 79,
#    'h': 79,
#    'left_eye': (74, 60),
#    'right_eye': (103, 60)}},
#  'time': 1.78}

# %%
df = DeepFace.find(img_path = 'sample_data/img1.jpg', db_path = 'sample_data/')
# Out:
# 24-04-03 18:15:54 - vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:05<00:00, 115MB/s]
# 24-04-03 18:16:02 - Found 64 newly added image(s), 0 removed image(s), 0 replaced image(s).
# Finding representations:   8%|▊         | 5/64 [00:07<01:31,  1.55s/it]
# 24-04-03 18:16:10 - 🔴 Exception while extracting faces from sample_data/img39.jpg: Exception while extracting faces from sample_data/img39.jpg.Consider to set enforce_detection arg to False.
# Finding representations: 100%|██████████| 64/64 [00:58<00:00,  1.09it/s]
# 24-04-03 18:17:01 - There are now 69 representations in ds_vggface_opencv_v2.pkl
# 24-04-03 18:17:01 - Searching sample_data/img1.jpg in 69 length datastore
# 24-04-03 18:17:02 - find function duration 68.96360993385315 seconds

# %%
df
# Out:
# [                            identity  \
#  0               sample_data/img1.jpg
#  1               sample_data/img2.jpg
#  2               sample_data/img4.jpg
#  3   sample_data/img11_reflection.jpg
#  4               sample_data/img6.jpg
#  5               sample_data/img7.jpg
#  6             sample_data/couple.jpg
#  7              sample_data/img11.jpg
#  8               sample_data/img5.jpg
#  9              sample_data/img10.jpg
#  10           sample_data/AJyoung.jpg
#
#                                          hash  target_x  target_y  target_w  \
#  0   7cebdc6ec7a17c91aa8f3e0f080c7637f6410bca       345       211       769
#  1   d597a11a08c68cbecf29d164e21283d2e42bb05e       516       192       512
#  2   c971407dbd475b5ad73348d9afbe4b84824e5a02       419       301       919
#  3   a3c3ce1a99ddff66efeefe890a40182a7254a511       224       167       707
#  4   638468c2369245679ffaa18c4366f16af691ccf3       118       223       531
# ...

# %%
plt.imshow(img1)

# %%
obj = DeepFace.analyze(img_path=img1_path)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 24-04-03 18:18:39 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 93.2MB/s]
# Action: age:  25%|██▌       | 1/4 [00:09<00:28,  9.64s/it]
# 24-04-03 18:18:49 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   6%|▌         | 30.9M/539M [00:00<00:01, 307MB/s]
#  15%|█▌        | 81.8M/539M [00:00<00:01, 424MB/s]
#  23%|██▎       | 124M/539M [00:00<00:01, 375MB/s]
#  30%|███       | 163M/539M [00:00<00:01, 353MB/s]
#  37%|███▋      | 199M/539M [00:00<00:01, 318MB/s]
# ...

# %%
obj
# Out:
# [{'emotion': {'angry': 3.0492219222742275e-22,
#    'disgust': 0.0,
#    'fear': 1.2102349108664894e-29,
#    'happy': 100.0,
#    'sad': 1.9902047932969674e-18,
#    'surprise': 5.459487462805557e-10,
#    'neutral': 5.2178578124895125e-08},
#   'dominant_emotion': 'happy',
#   'region': {'x': 345,
#    'y': 211,
#    'w': 769,
#    'h': 769,
#    'left_eye': (571, 517),
#    'right_eye': (853, 523)},
#   'face_confidence': 0.9,
#   'age': 31,
#   'gender': {'Woman': 99.99462366104126, 'Man': 0.005381566734286025},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 13.30370306968689,
#    'indian': 17.150703072547913,
#    'black': 4.891100153326988,
#    'white': 18.851839005947113,
#    'middle eastern': 17.36544966697693,
#    'latino hispanic': 28.43720316886902},
#   'dominant_race': 'latino hispanic'}]
